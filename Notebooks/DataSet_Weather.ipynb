# %% [markdown]
# # Weather Data Set
#
#
# In this notebook we import the weather data, preprocess if is needed and save as a new Data Frame.
#
#
# ### Historical Data
#
# For training and testing the model we use the historicla weather data related to our energy consumption data provided.
#
# For that, we'll use the API provided by [AT-Wetter](http://at-wetter.tk/index.php?men=api). We'll use this one, and not the OpenWeather API since if we want to get the historical data depth more than a week (we need a year) we'll have to use several queries.
#
#
# #### API
#
# This API don't need a Key or other autentication. It's located on the AT-Server in `http://at-wetter.tk/api/v1/.`
# The instruction to use it are in their [website](http://at-wetter.tk/index.php?men=api)
#
# #### Example
#
# To query **all the available stations** we need a call following the format:
# `/api/v1/[field]/[YYYY-MM-DD]/[day count]`
#
# A query call to `http://at-wetter.tk/api/v1/t/2014-08-01/2`  returns Temperature Data for every available station for 2014-08-01, 2 days in the past.
#
#
#
# To query just **one specific stations** we use:
#
# `/api/v1/station/[station]/[field]|[all]/[YYYY-MM-DD]/[day count]`
#
# This will return the `[field]` from the specified date `[YYYY-MM-DD]` and prints data `[day count]` days in the past for the specified stations `[station]`

# %% [markdown]
# ### Calling the API

# %%
import requests as rq
import json
import datetime as dt
import pandas as pd
import numpy as np

# %% [markdown]
# * See the available stations

# %%
URL ="http://at-wetter.tk/api/v1/stations"
response = rq.request("GET", URL)
print(response.text)
# Out:
# '11157';'Aigen im Ennstal';'640';'m'
# '11244';'Bad Gleichenberg';'280';'m'
# '11101';'Bregenz';'424';'m'
# '11190';'Eisenstadt';'184';'m'
# '11';'Feuerkogel';'1618';'m'
# '11155';'Feuerkogel';'1618';'m'
# '11240';'Graz/Flughafen';'340';'m'
# '11121';'Innsbruck';'579';'m'
# '11331';'Klagenfurt/Flughafen';'447';'m'
# '11012';'Kremsmünster';'383';'m'
# '11012';'Kremsm�nster';'383';'m'
# '11130';'Kufstein';'495';'m'
# '11204';'Lienz';'659';'m'
# '11010';'Linz/Hörsching';'298';'m'
# '11010';'Linz/H�rsching';'298';'m'
# '11171';'Mariazell';'866';'m'
# '11126';'Patscherkofel';'2247';'m'
# '11022';'Retz';'320';'m'
# '11150';'Salzburg';'430';'m'
# '11343';'Sonnblick';'3105';'m'
# '11389';'St. Pölten';'270';'m'
# '11389';'St. P�lten';'270';'m'
# '11265';'Villacher Alpe';'2140';'m'
# '11035';'Wien/Hohe Warte';'203';'m'
# '11036';'Wien/Schwechat';'183';'m'

# %% [markdown]
# * Calculate de day count from Building Energy Data set
#
# We need the day count in order to ask these exactly days to weather API to match it with our energy data set.
# We could do it manually, but in order to automated all the steps we'll calculated with a python script

# %%
import pandas as pd 
DataFrame = pd.read_excel("./DataSets/Raw_Building_energy_DataSet.xlsx", header=1)
DataFrame.head()

#Calculate the Delta Time 

start_date = dt.datetime.strptime(DataFrame['Time'][0], "%Y-%m-%d %H:%M:%S")
end_date = dt.datetime.strptime(DataFrame['Time'][len(DataFrame)-1], "%Y-%m-%d %H:%M:%S")
day_count = end_date - start_date
print(day_count)
# Out:
# 280 days, 5:00:00

# %% [markdown]
# As the `[daycount]` field for API Query doesn't allow hours, if we have any hours of difference between the start day and the end day, we add an extra day. Then in the data frame matching we'll delete the extra hours for the extra day.

# %%
dayCount=0 
if day_count.seconds //3600 > 0: 
    dayCount = day_count.days + 1
else: 
    dayCount = day_count.days
print(dayCount)
# Out:
# 281

# %% [markdown]
# * Download the weather data

# %%
station = '11240' #GRAZ 
field = 'all'  #Temperatuer
days_count = str(day_count.days)

URL = "http://at-wetter.tk/api/v1/station/"
URL += station 
URL += "/" + field
URL += "/" + str(end_date.year) + "-" + str(end_date.month) + "-" + str(end_date.day)
URL += "/" + str(dayCount)
response = rq.request("GET", URL)

print(URL)
#print(response.text)
type(response.text)
# Out:
# http://at-wetter.tk/api/v1/station/11240/all/2021-11-3/281
# str

# %%
#response.json(encoding="utf-8")
#print(response.text)

# %% [markdown]
# * Saving the data into a Data Frame
#
# Since the data can't be downloaded in JSON format, we first split the whole text into lineas, and then elements.

# %%
lines = response.text.splitlines()
ColumnNames = [ (col.replace("'",'')) for col in lines[0].split(";") ]
WeatDataFrame = pd.DataFrame(columns=ColumnNames, index=range(len(lines)-2)) # -1 cause the columnames and -1 again cuase it starts from 0

# %% [markdown]
# The index of the daframe starts from 0 but the first line of response.text is the ColumnName row. So we start from 0 for the DataFrame index and for idx+1 for lineas

# %%
for idx in range(len(lines)-2):  
    WeatDataFrame.iloc[idx] = [ (col.replace("'",'')) for col in lines[idx+1].split(";") ]
WeatDataFrame
# Out:
#      station            name hoehe       datum   zeit     t    tp  rf   wr  \
# 0      11240  Graz/Flughafen   340  2021-01-26  00:00  -3.1  -4.0  93  220
# 1      11240  Graz/Flughafen   340  2021-01-26  01:00  -3.3  -3.9  96  360
# 2      11240  Graz/Flughafen   340  2021-01-26  02:00  -2.8  -3.5  95  260
# 3      11240  Graz/Flughafen   340  2021-01-26  03:00  -3.8  -4.2  97  180
# 4      11240  Graz/Flughafen   340  2021-01-26  04:00  -4.7  -5.3  96  280
# ...      ...             ...   ...         ...    ...   ...   ...  ..  ...
# 6693   11240  Graz/Flughafen   340  2021-11-03  18:00   7.9   7.3  96  160
# 6694   11240  Graz/Flughafen   340  2021-11-03  19:00   7.6   7.0  96  230
# 6695   11240  Graz/Flughafen   340  2021-11-03  20:00   7.6   7.0  96    0
# 6696   11240  Graz/Flughafen   340  2021-11-03  21:00   7.9   7.5  97   80
# 6697   11240  Graz/Flughafen   340  2021-11-03  22:00   7.8   7.4  97    0
#
#        wg   wsr  wsg regen   ldred ldstat sonne            timestamp
# 0     1.8  null  7.6   0.0  1010.3  965.2     0  2021-01-26 00:10:10
# 1     3.6  null  5.4   0.0  1010.9  965.8     0  2021-01-26 01:10:09
# 2     5.4  null  7.6   0.0  1011.1  966.0     0  2021-01-26 02:10:08
# 3     5.4  null  7.6   0.0  1011.4  966.2     0  2021-01-26 03:10:08
# 4     1.8  null  9.4   0.0  1012.0  966.6     0  2021-01-26 04:10:09
# ...   ...   ...  ...   ...     ...    ...   ...                  ...
# 6693  5.4  null  9.4   0.2  1005.3  962.2     0  2021-11-03 18:10:10
# 6694  5.4  null  9.4   0.5  1004.7  961.6     0  2021-11-03 19:10:08
# 6695  1.8  null  9.4   0.9  1004.2  961.1     0  2021-11-03 20:10:12
# 6696  3.6  null  7.6   1.0  1003.8  960.8     0  2021-11-03 21:10:08
# 6697  1.8  null  5.4   0.6  1004.1  961.1     0  2021-11-03 22:10:09
#
# [6698 rows x 17 columns]

# %% [markdown]
# * Changing the datum and zeit column into a newone with datetime type object

# %%
WeatDataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6698 entries, 0 to 6697
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   station    6698 non-null   object
#  1   name       6698 non-null   object
#  2   hoehe      6698 non-null   object
#  3   datum      6698 non-null   object
#  4   zeit       6698 non-null   object
#  5   t          6698 non-null   object
#  6   tp         6698 non-null   object
#  7   rf         6698 non-null   object
#  8   wr         6698 non-null   object
#  9   wg         6698 non-null   object
#  10  wsr        6698 non-null   object
#  11  wsg        6698 non-null   object
#  12  regen      6698 non-null   object
#  13  ldred      6698 non-null   object
#  14  ldstat     6698 non-null   object
#  15  sonne      6698 non-null   object
#  16  timestamp  6698 non-null   object
# dtypes: object(17)
# memory usage: 889.7+ KB

# %%
WeatDataFrame["datum"][:]
# Out:
# 0       2021-01-26
# 1       2021-01-26
# 2       2021-01-26
# 3       2021-01-26
# 4       2021-01-26
#            ...
# 6693    2021-11-03
# 6694    2021-11-03
# 6695    2021-11-03
# 6696    2021-11-03
# 6697    2021-11-03
# Name: datum, Length: 6698, dtype: object

# %% [markdown]
# * Converting string type date to datetime type objects

# %%
from datetime import datetime as dt 

dates=[] 
for idx in range(len(WeatDataFrame["datum"])): 
    str_date = str(WeatDataFrame["datum"][idx]) + " " + str(WeatDataFrame["zeit"][idx])
    dt = dt.strptime(str_date, "%Y-%m-%d %H:%M")
    dates.append(dt)

print(len(dates), len(WeatDataFrame.index))
WeatDataFrame.insert(0,"Time",dates)
# Out:
# 6698 6698

# %%
WeatDataFrame
# Out:
#                     Time station            name hoehe       datum   zeit  \
# 0    2021-01-26 00:00:00   11240  Graz/Flughafen   340  2021-01-26  00:00
# 1    2021-01-26 01:00:00   11240  Graz/Flughafen   340  2021-01-26  01:00
# 2    2021-01-26 02:00:00   11240  Graz/Flughafen   340  2021-01-26  02:00
# 3    2021-01-26 03:00:00   11240  Graz/Flughafen   340  2021-01-26  03:00
# 4    2021-01-26 04:00:00   11240  Graz/Flughafen   340  2021-01-26  04:00
# ...                  ...     ...             ...   ...         ...    ...
# 6693 2021-11-03 18:00:00   11240  Graz/Flughafen   340  2021-11-03  18:00
# 6694 2021-11-03 19:00:00   11240  Graz/Flughafen   340  2021-11-03  19:00
# 6695 2021-11-03 20:00:00   11240  Graz/Flughafen   340  2021-11-03  20:00
# 6696 2021-11-03 21:00:00   11240  Graz/Flughafen   340  2021-11-03  21:00
# 6697 2021-11-03 22:00:00   11240  Graz/Flughafen   340  2021-11-03  22:00
#
#          t    tp  rf   wr   wg   wsr  wsg regen   ldred ldstat sonne  \
# 0     -3.1  -4.0  93  220  1.8  null  7.6   0.0  1010.3  965.2     0
# 1     -3.3  -3.9  96  360  3.6  null  5.4   0.0  1010.9  965.8     0
# 2     -2.8  -3.5  95  260  5.4  null  7.6   0.0  1011.1  966.0     0
# 3     -3.8  -4.2  97  180  5.4  null  7.6   0.0  1011.4  966.2     0
# 4     -4.7  -5.3  96  280  1.8  null  9.4   0.0  1012.0  966.6     0
# ...    ...   ...  ..  ...  ...   ...  ...   ...     ...    ...   ...
# 6693   7.9   7.3  96  160  5.4  null  9.4   0.2  1005.3  962.2     0
# 6694   7.6   7.0  96  230  5.4  null  9.4   0.5  1004.7  961.6     0
# 6695   7.6   7.0  96    0  1.8  null  9.4   0.9  1004.2  961.1     0
# 6696   7.9   7.5  97   80  3.6  null  7.6   1.0  1003.8  960.8     0
# 6697   7.8   7.4  97    0  1.8  null  5.4   0.6  1004.1  961.1     0
#
#                 timestamp
# 0     2021-01-26 00:10:10
# 1     2021-01-26 01:10:09
# 2     2021-01-26 02:10:08
# 3     2021-01-26 03:10:08
# 4     2021-01-26 04:10:09
# ...                   ...
# 6693  2021-11-03 18:10:10
# 6694  2021-11-03 19:10:08
# 6695  2021-11-03 20:10:12
# 6696  2021-11-03 21:10:08
# 6697  2021-11-03 22:10:09
#
# [6698 rows x 18 columns]

# %% [markdown]
# * Deleting the timestamps column, zatum and zeit

# %%
WeatDataFrame.drop('datum', inplace = True, axis=1) 
WeatDataFrame.drop('zeit', inplace = True, axis=1) 
WeatDataFrame.drop('timestamp', inplace = True, axis=1)

# %% [markdown]
# Save the data frame into a csv file

# %%
WeatDataFrame.to_csv("./DataSets/Raw_Weather_DataSet.csv",index=False)

# %% [markdown]
# ### Forecast
# #### API
#
# We'll use python to request de dataset from the OpenWeather data base. The API  request call should be in this format:
#
# ``` http://history.openweathermap.org/data/2.5/history/city?q={city ID},{country code}&type=hour&start={start}&end={end}&appid={API key}```
#
# #### Usage
#
# Once we introduce the day that we want to predict we request for that day's forecast. If we have it, we arrange all the necessarry inputs for that day (temp, holiday, week day,etc) and we introduce them into the model.

# %%
URL = " http://api.openweathermap.org/data/2.5/forecast?q=Graz&appid=" + API_KEY
response = rq.request("GET", URL)
print(response.json()["list"])
# Out:
# [{'dt': 1637852400, 'main': {'temp': 276.43, 'feels_like': 276.43, 'temp_min': 276.43, 'temp_max': 276.47, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 966, 'humidity': 57, 'temp_kf': -0.04}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 31}, 'wind': {'speed': 0.4, 'deg': 341, 'gust': 0.55}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2021-11-25 15:00:00'}, {'dt': 1637863200, 'main': {'temp': 275.99, 'feels_like': 275.99, 'temp_min': 275.78, 'temp_max': 275.99, 'pressure': 1009, 'sea_level': 1009, 'grnd_level': 965, 'humidity': 63, 'temp_kf': 0.21}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 53}, 'wind': {'speed': 1.09, 'deg': 301, 'gust': 1.05}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2021-11-25 18:00:00'}, {'dt': 1637874000, 'main': {'temp': 276.02, 'feels_like': 276.02, 'temp_min': 276.02, 'temp_max': 276.02, 'pressure': 1008, 'sea_level': 1008, 'grnd_level': 964, 'humidity': 74, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 95}, 'wind': {'speed': 0.93, 'deg': 305, 'gust': 0.92}, 'visibility': 10000, 'pop': 0.01, 'sys': {'pod': 'n'}, 'dt_txt': '2021-11-25 21:00:00'}, {'dt': 1637884800, 'main': {'temp': 277, 'feels_like': 275.99, 'temp_min': 277, 'temp_max': 277, 'pressure': 1007, 'sea_level': 1007, 'grnd_level': 963, 'humidity': 79, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 97}, 'wind': {'speed': 1.36, 'deg': 330, 'gust': 1.43}, 'visibility': 10000, 'pop': 0.2, 'rain': {'3h': 0.28}, 'sys': {'pod': 'n'}, 'dt_txt': '2021-11-26 00:00:00'}, {'dt': 1637895600, 'main': {'temp': 277.32, 'feels_like': 277.32, 'temp_min': 277.32, 'temp_max': 277.32, 'pressure': 1004, 'sea_level': 1004, 'grnd_level': 960, 'humidity': 88, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.19, 'deg': 9, 'gust': 1.35}, 'visibility': 10000, 'pop': 0.49, 'rain': {'3h': 0.54}, 'sys': {'pod': 'n'}, 'dt_txt': '2021-11-26 03:00:00'}, {'dt': 1637906400, 'main': {'temp': 277.12, 'feels_like': 277.12, 'temp_min': 277.12, 'temp_max': 277.12, 'pressure': 1002, 'sea_level': 1002, 'grnd_level': 958, 'humidity': 86, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.21, 'deg': 19, 'gust': 2.48}, 'visibility': 10000, 'pop': 0.64, 'rain': {'3h': 0.24}, 'sys': {'pod': 'n'}, 'dt_txt': '2021-11-26 06:00:00'}, {'dt': 1637917200, 'main': {'temp': 275.84, 'feels_like': 275.84, 'temp_min': 275.84, 'temp_max': 275.84, 'pressure': 1001, 'sea_level': 1001, 'grnd_level': 958, 'humidity': 97, 'temp_kf': 0}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'clouds': {'all': 100}, 'wind': {'speed': 0.71, 'deg': 181, 'gust': 1.93}, 'visibility': 917, 'pop': 1, 'snow': {'3h': 2.4}, 'sys': {'pod': 'd'}, 'dt_txt': '2021-11-26 09:00:00'}, {'dt': 1637928000, 'main': {'temp': 275.14, 'feels_like': 275.14, 'temp_min': 275.14, 'temp_max': 275.14, 'pressure': 998, 'sea_level': 998, 'grnd_level': 954, 'humidity': 99, 'temp_kf': 0}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.29, 'deg': 319, 'gust': 2.61}, 'visibility': 72, 'pop': 1, 'snow': {'3h': 7.13}, 'sys': {'pod': 'd'}, 'dt_txt': '2021-11-26 12:00:00'}, {'dt': 1637938800, 'main': {'temp': 274.9, 'feels_like': 274.9, 'temp_min': 274.9, 'temp_max': 274.9, 'pressure': 998, 'sea_level': 998, 'grnd_level': 954, 'humidity': 100, 'temp_kf': 0}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'clouds': {'all': 100}, 'wind': {'speed': 0.62, 'deg': 296, 'gust': 1.19}, 'visibility': 34, 'pop':  ...

# %%
response.json()["list"]
# Out:
# [{'dt': 1637852400,
#   'main': {'temp': 276.43,
#    'feels_like': 276.43,
#    'temp_min': 276.43,
#    'temp_max': 276.47,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 966,
#    'humidity': 57,
#    'temp_kf': -0.04},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 31},
#   'wind': {'speed': 0.4, 'deg': 341, 'gust': 0.55},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-25 15:00:00'},
#  {'dt': 1637863200,
#   'main': {'temp': 275.99,
#    'feels_like': 275.99,
#    'temp_min': 275.78,
#    'temp_max': 275.99,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 965,
#    'humidity': 63,
#    'temp_kf': 0.21},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 53},
#   'wind': {'speed': 1.09, 'deg': 301, 'gust': 1.05},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-25 18:00:00'},
#  {'dt': 1637874000,
#   'main': {'temp': 276.02,
#    'feels_like': 276.02,
#    'temp_min': 276.02,
#    'temp_max': 276.02,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 964,
#    'humidity': 74,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 0.93, 'deg': 305, 'gust': 0.92},
#   'visibility': 10000,
#   'pop': 0.01,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-25 21:00:00'},
#  {'dt': 1637884800,
#   'main': {'temp': 277,
#    'feels_like': 275.99,
#    'temp_min': 277,
#    'temp_max': 277,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 963,
#    'humidity': 79,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 1.36, 'deg': 330, 'gust': 1.43},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.28},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-26 00:00:00'},
#  {'dt': 1637895600,
#   'main': {'temp': 277.32,
#    'feels_like': 277.32,
#    'temp_min': 277.32,
#    'temp_max': 277.32,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 960,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.19, 'deg': 9, 'gust': 1.35},
#   'visibility': 10000,
#   'pop': 0.49,
#   'rain': {'3h': 0.54},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-26 03:00:00'},
#  {'dt': 1637906400,
#   'main': {'temp': 277.12,
#    'feels_like': 277.12,
#    'temp_min': 277.12,
#    'temp_max': 277.12,
#    'pressure': 1002,
#    'sea_level': 1002,
#    'grnd_level': 958,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.21, 'deg': 19, 'gust': 2.48},
#   'visibility': 10000,
#   'pop': 0.64,
#   'rain': {'3h': 0.24},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-26 06:00:00'},
#  {'dt': 1637917200,
#   'main': {'temp': 275.84,
#    'feels_like': 275.84,
#    'temp_min': 275.84,
#    'temp_max': 275.84,
#    'pressure': 1001,
#    'sea_level': 1001,
#    'grnd_level': 958,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.71, 'deg': 181, 'gust': 1.93},
#   'visibility': 917,
#   'pop': 1,
#   'snow': {'3h': 2.4},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-26 09:00:00'},
#  {'dt': 1637928000,
#   'main': {'temp': 275.14,
#    'feels_like': 275.14,
#    'temp_min': 275.14,
#    'temp_max': 275.14,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 954,
#    'humidity': 99,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.29, 'deg': 319, 'gust': 2.61},
#   'visibility': 72,
#   'pop': 1,
#   'snow': {'3h': 7.13},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-26 12:00:00'},
#  {'dt': 1637938800,
#   'main': {'temp': 274.9,
#    'feels_like': 274.9,
#    'temp_min': 274.9,
#    'temp_max': 274.9,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 954,
#    'humidity': 100,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.62, 'deg': 296, 'gust': 1.19},
#   'visibility': 34,
#   'pop': 1,
#   'snow': {'3h': 4.9},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-26 15:00:00'},
#  {'dt': 1637949600,
#   'main': {'temp': 274.88,
#    'feels_like': 274.88,
#    'temp_min': 274.88,
#    'temp_max': 274.88,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 955,
#    'humidity': 99,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.81, 'deg': 295, 'gust': 2.51},
#   'visibility': 129,
#   'pop': 1,
#   'snow': {'3h': 1.45},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-26 18:00:00'},
#  {'dt': 1637960400,
#   'main': {'temp': 273.76,
#    'feels_like': 273.76,
#    'temp_min': 273.76,
#    'temp_max': 273.76,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 954,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 1.08, 'deg': 304, 'gust': 1.4},
#   'visibility': 10000,
#   'pop': 0.24,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-26 21:00:00'},
#  {'dt': 1637971200,
#   'main': {'temp': 273.26,
#    'feels_like': 273.26,
#    'temp_min': 273.26,
#    'temp_max': 273.26,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 954,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 0.71, 'deg': 347, 'gust': 0.66},
#   'visibility': 10000,
#   'pop': 0.17,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-27 00:00:00'},
#  {'dt': 1637982000,
#   'main': {'temp': 272.97,
#    'feels_like': 272.97,
#    'temp_min': 272.97,
#    'temp_max': 272.97,
#    'pressure': 997,
#    'sea_level': 997,
#    'grnd_level': 953,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 0.53, 'deg': 16, 'gust': 0.61},
#   'visibility': 5305,
#   'pop': 0.44,
#   'snow': {'3h': 0.18},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-27 03:00:00'},
#  {'dt': 1637992800,
#   'main': {'temp': 273.55,
#    'feels_like': 273.55,
#    'temp_min': 273.55,
#    'temp_max': 273.55,
#    'pressure': 997,
#    'sea_level': 997,
#    'grnd_level': 953,
#    'humidity': 98,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 1.02, 'deg': 33, 'gust': 1.78},
#   'visibility': 84,
#   'pop': 0.83,
#   'snow': {'3h': 1.4},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-27 06:00:00'},
#  {'dt': 1638003600,
#   'main': {'temp': 274.18,
#    'feels_like': 274.18,
#    'temp_min': 274.18,
#    'temp_max': 274.18,
#    'pressure': 997,
#    'sea_level': 997,
#    'grnd_level': 953,
#    'humidity': 99,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.19, 'deg': 88, 'gust': 2.97},
#   'visibility': 119,
#   'pop': 0.79,
#   'snow': {'3h': 0.66},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-27 09:00:00'},
#  {'dt': 1638014400,
#   'main': {'temp': 274.45,
#    'feels_like': 274.45,
#    'temp_min': 274.45,
#    'temp_max': 274.45,
#    'pressure': 995,
#    'sea_level': 995,
#    'grnd_level': 952,
#    'humidity': 99,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.77, 'deg': 36, 'gust': 1.45},
#   'visibility': 64,
#   'pop': 0.79,
#   'snow': {'3h': 0.91},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-27 12:00:00'},
#  {'dt': 1638025200,
#   'main': {'temp': 274.38,
#    'feels_like': 274.38,
#    'temp_min': 274.38,
#    'temp_max': 274.38,
#    'pressure': 995,
#    'sea_level': 995,
#    'grnd_level': 952,
#    'humidity': 100,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.66, 'deg': 305, 'gust': 1.26},
#   'visibility': 56,
#   'pop': 0.71,
#   'snow': {'3h': 0.57},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-27 15:00:00'},
#  {'dt': 1638036000,
#   'main': {'temp': 272.91,
#    'feels_like': 271.27,
#    'temp_min': 272.91,
#    'temp_max': 272.91,
#    'pressure': 997,
#    'sea_level': 997,
#    'grnd_level': 953,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 1.41, 'deg': 313, 'gust': 2.03},
#   'visibility': 9857,
#   'pop': 0.4,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-27 18:00:00'},
#  {'dt': 1638046800,
#   'main': {'temp': 272.8,
#    'feels_like': 272.8,
#    'temp_min': 272.8,
#    'temp_max': 272.8,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 954,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 0.95, 'deg': 348, 'gust': 0.88},
#   'visibility': 10000,
#   'pop': 0.29,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-27 21:00:00'},
#  {'dt': 1638057600,
#   'main': {'temp': 273.98,
#    'feels_like': 272.52,
#    'temp_min': 273.98,
#    'temp_max': 273.98,
#    'pressure': 996,
#    'sea_level': 996,
#    'grnd_level': 952,
#    'humidity': 98,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 1.39, 'deg': 337, 'gust': 3},
#   'visibility': 273,
#   'pop': 0.91,
#   'snow': {'3h': 2.2},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-28 00:00:00'},
#  {'dt': 1638068400,
#   'main': {'temp': 274.02,
#    'feels_like': 274.02,
#    'temp_min': 274.02,
#    'temp_max': 274.02,
#    'pressure': 996,
#    'sea_level': 996,
#    'grnd_level': 952,
#    'humidity': 100,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.02, 'deg': 323, 'gust': 1.79},
#   'visibility': 70,
#   'pop': 1,
#   'snow': {'3h': 11.98},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-28 03:00:00'},
#  {'dt': 1638079200,
#   'main': {'temp': 273.71,
#    'feels_like': 273.71,
#    'temp_min': 273.71,
#    'temp_max': 273.71,
#    'pressure': 996,
#    'sea_level': 996,
#    'grnd_level': 953,
#    'humidity': 99,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.28, 'deg': 314, 'gust': 3.46},
#   'visibility': 296,
#   'pop': 1,
#   'snow': {'3h': 3.97},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-28 06:00:00'},
#  {'dt': 1638090000,
#   'main': {'temp': 274.17,
#    'feels_like': 274.17,
#    'temp_min': 274.17,
#    'temp_max': 274.17,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 954,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 0.96, 'deg': 296, 'gust': 2.43},
#   'visibility': 6597,
#   'pop': 0.43,
#   'snow': {'3h': 0.29},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-28 09:00:00'},
#  {'dt': 1638100800,
#   'main': {'temp': 274.54,
#    'feels_like': 274.54,
#    'temp_min': 274.54,
#    'temp_max': 274.54,
#    'pressure': 997,
#    'sea_level': 997,
#    'grnd_level': 953,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 88},
#   'wind': {'speed': 0.34, 'deg': 1, 'gust': 0.7},
#   'visibility': 5825,
#   'pop': 0.29,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-28 12:00:00'},
#  {'dt': 1638111600,
#   'main': {'temp': 273.19,
#    'feels_like': 273.19,
#    'temp_min': 273.19,
#    'temp_max': 273.19,
#    'pressure': 998,
#    'sea_level': 998,
#    'grnd_level': 954,
#    'humidity': 99,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 0.89, 'deg': 129, 'gust': 1.41},
#   'visibility': 2806,
#   'pop': 0.04,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-28 15:00:00'},
#  {'dt': 1638122400,
#   'main': {'temp': 273.54,
#    'feels_like': 273.54,
#    'temp_min': 273.54,
#    'temp_max': 273.54,
#    'pressure': 999,
#    'sea_level': 999,
#    'grnd_level': 955,
#    'humidity': 100,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 0.87, 'deg': 34, 'gust': 1.68},
#   'visibility': 176,
#   'pop': 0.36,
#   'snow': {'3h': 0.14},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-28 18:00:00'},
#  {'dt': 1638133200,
#   'main': {'temp': 273.47,
#    'feels_like': 273.47,
#    'temp_min': 273.47,
#    'temp_max': 273.47,
#    'pressure': 999,
#    'sea_level': 999,
#    'grnd_level': 955,
#    'humidity': 99,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.27, 'deg': 21, 'gust': 3.35},
#   'visibility': 93,
#   'pop': 0.59,
#   'snow': {'3h': 0.53},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-28 21:00:00'},
#  {'dt': 1638144000,
#   'main': {'temp': 272.21,
#    'feels_like': 269.35,
#    'temp_min': 272.21,
#    'temp_max': 272.21,
#    'pressure': 1000,
#    'sea_level': 1000,
#    'grnd_level': 955,
#    'humidity': 98,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.2, 'deg': 342, 'gust': 4.54},
#   'visibility': 205,
#   'pop': 0.79,
#   'snow': {'3h': 3.66},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-29 00:00:00'},
#  {'dt': 1638154800,
#   'main': {'temp': 271.75,
#    'feels_like': 269.5,
#    'temp_min': 271.75,
#    'temp_max': 271.75,
#    'pressure': 1000,
#    'sea_level': 1000,
#    'grnd_level': 956,
#    'humidity': 98,
#    'temp_kf': 0},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.69, 'deg': 337, 'gust': 4.01},
#   'visibility': 960,
#   'pop': 0.96,
#   'snow': {'3h': 2.75},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-29 03:00:00'},
#  {'dt': 1638165600,
#   'main': {'temp': 270.7,
#    'feels_like': 270.7,
#    'temp_min': 270.7,
#    'temp_max': 270.7,
#    'pressure': 1001,
#    'sea_level': 1001,
#    'grnd_level': 957,
#    'humidity': 97,
#    'temp_kf': 0},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.97, 'deg': 298, 'gust': 1.23},
#   'visibility': 10000,
#   'pop': 0.79,
#   'snow': {'3h': 0.91},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-29 06:00:00'},
#  {'dt': 1638176400,
#   'main': {'temp': 272.35,
#    'feels_like': 269.85,
#    'temp_min': 272.35,
#    'temp_max': 272.35,
#    'pressure': 1002,
#    'sea_level': 1002,
#    'grnd_level': 958,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 1.93, 'deg': 308, 'gust': 3.55},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-29 09:00:00'},
#  {'dt': 1638187200,
#   'main': {'temp': 274.46,
#    'feels_like': 273.01,
#    'temp_min': 274.46,
#    'temp_max': 274.46,
#    'pressure': 1002,
#    'sea_level': 1002,
#    'grnd_level': 958,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 85},
#   'wind': {'speed': 1.42, 'deg': 306, 'gust': 4.32},
#   'visibility': 10000,
#   'pop': 0.02,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-29 12:00:00'},
#  {'dt': 1638198000,
#   'main': {'temp': 270.47,
#    'feels_like': 270.47,
#    'temp_min': 270.47,
#    'temp_max': 270.47,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 959,
#    'humidity': 96,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 39},
#   'wind': {'speed': 1.11, 'deg': 289, 'gust': 1.11},
#   'visibility': 10000,
#   'pop': 0.02,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-29 15:00:00'},
#  {'dt': 1638208800,
#   'main': {'temp': 268.14,
#    'feels_like': 265.12,
#    'temp_min': 268.14,
#    'temp_max': 268.14,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 963,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 44},
#   'wind': {'speed': 1.83, 'deg': 316, 'gust': 2.09},
#   'visibility': 10000,
#   'pop': 0.17,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-29 18:00:00'},
#  {'dt': 1638219600,
#   'main': {'temp': 266.51,
#    'feels_like': 263.08,
#    'temp_min': 266.51,
#    'temp_max': 266.51,
#    'pressure': 1011,
#    'sea_level': 1011,
#    'grnd_level': 965,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 1.92, 'deg': 306, 'gust': 1.74},
#   'visibility': 10000,
#   'pop': 0.25,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-29 21:00:00'},
#  {'dt': 1638230400,
#   'main': {'temp': 266.05,
#    'feels_like': 262.75,
#    'temp_min': 266.05,
#    'temp_max': 266.05,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 966,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 1.8, 'deg': 306, 'gust': 1.64},
#   'visibility': 10000,
#   'pop': 0.25,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-30 00:00:00'},
#  {'dt': 1638241200,
#   'main': {'temp': 265.59,
#    'feels_like': 262.34,
#    'temp_min': 265.59,
#    'temp_max': 265.59,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 968,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 38},
#   'wind': {'speed': 1.73, 'deg': 310, 'gust': 1.71},
#   'visibility': 10000,
#   'pop': 0.13,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-30 03:00:00'},
#  {'dt': 1638252000,
#   'main': {'temp': 265.47,
#    'feels_like': 262.37,
#    'temp_min': 265.47,
#    'temp_max': 265.47,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 971,
#    'humidity': 95,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 32},
#   'wind': {'speed': 1.64, 'deg': 301, 'gust': 1.94},
#   'visibility': 10000,
#   'pop': 0.13,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2021-11-30 06:00:00'},
#  {'dt': 1638262800,
#   'main': {'temp': 271.24,
#    'feels_like': 271.24,
#    'temp_min': 271.24,
#    'temp_max': 271.24,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 972,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 0.93, 'deg': 272, 'gust': 2.3},
#   'visibility': 10000,
#   'pop': 0.09,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-30 09:00:00'},
#  {'dt': 1638273600,
#   'main': {'temp': 274.07,
#    'feels_like': 274.07,
#    'temp_min': 274.07,
#    'temp_max': 274.07,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 971,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 0.7, 'deg': 205, 'gust': 1.45},
#   'visibility': 10000,
#   'pop': 0.13,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2021-11-30 12:00:00'}]

# %%
df= pd.DataFrame(response.json()['list'])

# %%
df.head()
# Out:
#            dt                                               main  \
# 0  1637582400  {'temp': 278.73, 'feels_like': 278.73, 'temp_m...
# 1  1637593200  {'temp': 279.18, 'feels_like': 279.18, 'temp_m...
# 2  1637604000  {'temp': 278.91, 'feels_like': 278.91, 'temp_m...
# 3  1637614800  {'temp': 278.48, 'feels_like': 278.48, 'temp_m...
# 4  1637625600  {'temp': 277.29, 'feels_like': 277.29, 'temp_m...
#
#                                              weather        clouds  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...   {'all': 83}
# 1  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 92}
# 2  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 3  [{'id': 804, 'main': 'Clouds', 'description': ...  {'all': 100}
# 4  [{'id': 804, 'main': 'Clouds', 'description': ...   {'all': 99}
#
#                                         wind  visibility   pop           sys  \
# 0   {'speed': 0.7, 'deg': 308, 'gust': 1.61}       10000  0.16  {'pod': 'd'}
# 1    {'speed': 0.48, 'deg': 2, 'gust': 1.34}       10000  0.09  {'pod': 'd'}
# 2  {'speed': 0.31, 'deg': 127, 'gust': 1.55}       10000  0.25  {'pod': 'n'}
# 3  {'speed': 0.58, 'deg': 326, 'gust': 0.99}       10000  0.22  {'pod': 'n'}
# 4  {'speed': 1.16, 'deg': 343, 'gust': 1.39}       10000  0.10  {'pod': 'n'}
#
#                 dt_txt rain
# 0  2021-11-22 12:00:00  NaN
# 1  2021-11-22 15:00:00  NaN
# 2  2021-11-22 18:00:00  NaN
# 3  2021-11-22 21:00:00  NaN
# 4  2021-11-23 00:00:00  NaN

# %% [markdown]
# * Creating a new data frame with only:
#
#  * Temperature date
#  * Timestamps (not Unix Time but string dates)

# %%
temp = [] 
timestamp=  [] 
FDf = pd.DataFrame()
for idx,value in enumerate(df['main']): 
    #print(value['temp'])
    #print(df['dt_txt'][idx])
    temp.append(value['temp']-273.15) #Kelvin to celsius 
    timestamp.append(df['dt_txt'][idx])

# %%
FDf.insert(0,'Time',timestamp)

# %%
FDf.insert(1,'t',temp)

# %%
FDf.head()
# Out:
#                   Time     t
# 0  2021-11-22 12:00:00  5.58
# 1  2021-11-22 15:00:00  6.03
# 2  2021-11-22 18:00:00  5.76
# 3  2021-11-22 21:00:00  5.33
# 4  2021-11-23 00:00:00  4.14

# %% [markdown]
#  * Converting into datetime type objects

# %%
from datetime import datetime as dt
def Convertstr2dt(data,col): 
    dates=[]
    for str_date in data[col]: 
        dti = dt.strptime(str_date, "%Y-%m-%d %H:%M:%S")
        dates.append(dti)
   
    #Delete the old column
    data.drop(col, inplace = True, axis=1) 

    #Insert the newone
    data.insert(0, col,dates)
    return data

DataFrame = Convertstr2dt(FDf,'Time')

# %%
DataFrame.head()
# Out:
#                  Time     t
# 0 2021-11-22 12:00:00  5.58
# 1 2021-11-22 15:00:00  6.03
# 2 2021-11-22 18:00:00  5.76
# 3 2021-11-22 21:00:00  5.33
# 4 2021-11-23 00:00:00  4.14

# %% [markdown]
# ### Adding the others inputs columns
#
# We create the whole input dataframe matching these forecast days.
#
# * Identify the week days

# %%
weekday = [] 
for day in DataFrame['Time']: 
    weekday.append(day.weekday())

#Add the new column
DataFrame.insert(1, 'Week Day',weekday)
DataFrame.head()
# Out:
#                  Time  Week Day     t
# 0 2021-11-22 12:00:00         0  5.58
# 1 2021-11-22 15:00:00         0  6.03
# 2 2021-11-22 18:00:00         0  5.76
# 3 2021-11-22 21:00:00         0  5.33
# 4 2021-11-23 00:00:00         1  4.14

# %% [markdown]
# #### Decoding the weekdays

# %%
import math
WeekDaysNorm = 2 * math.pi * DataFrame["Week Day"] / (DataFrame["Week Day"].max()+1) #+1 cause we start from 0

DataFrame["cos_x"] = np.cos(WeekDaysNorm)
DataFrame["sin_x"] = np.sin(WeekDaysNorm)

DataFrame.head(100)
# Out:
#                   Time  Week Day     t  cos_x         sin_x
# 0  2021-11-22 12:00:00         0  5.58    1.0  0.000000e+00
# 1  2021-11-22 15:00:00         0  6.03    1.0  0.000000e+00
# 2  2021-11-22 18:00:00         0  5.76    1.0  0.000000e+00
# 3  2021-11-22 21:00:00         0  5.33    1.0  0.000000e+00
# 4  2021-11-23 00:00:00         1  4.14    0.5  8.660254e-01
# 5  2021-11-23 03:00:00         1  3.60    0.5  8.660254e-01
# 6  2021-11-23 06:00:00         1  2.94    0.5  8.660254e-01
# 7  2021-11-23 09:00:00         1  5.82    0.5  8.660254e-01
# 8  2021-11-23 12:00:00         1  7.67    0.5  8.660254e-01
# 9  2021-11-23 15:00:00         1  4.97    0.5  8.660254e-01
# 10 2021-11-23 18:00:00         1  2.61    0.5  8.660254e-01
# 11 2021-11-23 21:00:00         1  1.56    0.5  8.660254e-01
# 12 2021-11-24 00:00:00         2  0.89   -0.5  8.660254e-01
# 13 2021-11-24 03:00:00         2  0.37   -0.5  8.660254e-01
# 14 2021-11-24 06:00:00         2 -0.14   -0.5  8.660254e-01
# 15 2021-11-24 09:00:00         2  3.63   -0.5  8.660254e-01
# 16 2021-11-24 12:00:00         2  5.84   -0.5  8.660254e-01
# 17 2021-11-24 15:00:00         2  3.02   -0.5  8.660254e-01
# 18 2021-11-24 18:00:00         2  1.06   -0.5  8.660254e-01
# 19 2021-11-24 21:00:00         2  0.35   -0.5  8.660254e-01
# 20 2021-11-25 00:00:00         3 -0.07   -1.0  1.224647e-16
# 21 2021-11-25 03:00:00         3 -0.37   -1.0  1.224647e-16
# 22 2021-11-25 06:00:00         3 -0.39   -1.0  1.224647e-16
# 23 2021-11-25 09:00:00         3  4.03   -1.0  1.224647e-16
# 24 2021-11-25 12:00:00         3  7.65   -1.0  1.224647e-16
# 25 2021-11-25 15:00:00         3  4.77   -1.0  1.224647e-16
# 26 2021-11-25 18:00:00         3  3.67   -1.0  1.224647e-16
# 27 2021-11-25 21:00:00         3  3.67   -1.0  1.224647e-16
# 28 2021-11-26 00:00:00         4  3.88   -0.5 -8.660254e-01
# 29 2021-11-26 03:00:00         4  4.73   -0.5 -8.660254e-01
# 30 2021-11-26 06:00:00         4  4.39   -0.5 -8.660254e-01
# 31 2021-11-26 09:00:00         4  4.55   -0.5 -8.660254e-01
# 32 2021-11-26 12:00:00         4  4.59   -0.5 -8.660254e-01
# 33 2021-11-26 15:00:00         4  4.79   -0.5 -8.660254e-01
# 34 2021-11-26 18:00:00         4  4.20   -0.5 -8.660254e-01
# 35 2021-11-26 21:00:00         4  4.34   -0.5 -8.660254e-01
# 36 2021-11-27 00:00:00         5  3.98    0.5 -8.660254e-01
# 37 2021-11-27 03:00:00         5  3.33    0.5 -8.660254e-01
# 38 2021-11-27 06:00:00         5  2.75    0.5 -8.660254e-01
# 39 2021-11-27 09:00:00         5  2.68    0.5 -8.660254e-01

# %% [markdown]
# #### Holidays matching

# %%
from datetime import date 
import holidays 
holidaysList = [] 

for day, name in sorted(holidays.AT(state='9', years=2021).items()): 
    holidaysList.append(day)
    
print(holidaysList, len(holidaysList))

DataFrame.insert(1,"Holiday",np.zeros(len(DataFrame)))
for i,date in enumerate(DataFrame['Time']):
    if date in holidaysList: 
        DataFrame["Holiday"].loc[i] = 1
# Out:
# [datetime.date(2021, 1, 1), datetime.date(2021, 1, 6), datetime.date(2021, 4, 5), datetime.date(2021, 5, 1), datetime.date(2021, 5, 13), datetime.date(2021, 5, 24), datetime.date(2021, 6, 3), datetime.date(2021, 8, 15), datetime.date(2021, 10, 26), datetime.date(2021, 11, 1), datetime.date(2021, 12, 8), datetime.date(2021, 12, 25), datetime.date(2021, 12, 26)] 13

# %%
def SaveDataFrame(data, name): 
    data.to_csv(name,index=False)
    return

# %%
SaveDataFrame(DataFrame,"./DataSets/Forecast_DataSet.csv")
